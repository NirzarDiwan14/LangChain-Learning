# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
print(os.getenv("MISTRAL_API_KEY"))
# Out:
# OtgDyfhHaPuJrQJSqj3NFzCZvhtmD0vS

# %%
from langchain_mistralai import ChatMistralAI

llm = ChatMistralAI(
    model="mistral-large-latest",
    temperature=0,
    max_retries=2
)

# %%
response = llm.invoke("What is the capital of sri lanka?")
print(response.content)
# Out:
# The capital of Sri Lanka is **Colombo** (the commercial capital) and **Sri Jayawardenepura Kotte** (the administrative capital).
#
# - **Colombo** is the largest city and the main economic hub.
# - **Sri Jayawardenepura Kotte** (often called **Kotte**) is the official legislative capital, where the Parliament of Sri Lanka is located.
#
# So, depending on the context, both cities are considered capitals.

# %%
master_ans = {
  "id": "7b3c4f4e-2c6e-4a9b-9f25-9f3e2c0a9c1a",
  "teacher_assignment_id": "3f1a2b9c-8d4e-4c7a-9e12-1a2b3c4d5e6f",
  "question_no": 1,
  "question_text": "Explain the process of photosynthesis.",
  "AI_generated_answer": "Photosynthesis is the process by which green plants use sunlight, carbon dioxide, and water to produce glucose and oxygen.",
  "teacher_feedback": "None",
  "max_marks": 5,
  "topic": "Photosynthesis",
  "standard": 7,
  "created_at": "2026-02-20T10:15:30.123456Z",
  "updated_at": "2026-02-20T10:15:30.123456Z"
}

# %%
student_assignment = {
  "id": "5f2a8c3d-9e41-4b7a-a123-9d8e7c6b5a4f",
  "teacher_assignment_id": "3f1a2b9c-8d4e-4c7a-9e12-1a2b3c4d5e6f",
  "file_url": "https://storage.example.com/assignments/student_123_answer.pdf",
  "file_name": "science_assignment_1.pdf",
  "user_id": "a9b8c7d6-e5f4-3210-9abc-def123456789",
  "created_at": "2026-02-20T14:30:00Z",
  "updated_at": "2026-02-20T14:30:00Z"
}

# %%
student_answer = {
  "id": "c4a1f2e3-9b8d-4a6f-8e12-1f2a3b4c5d6e",
  "student_assignment_id": "a1b2c3d4-5e6f-7890-abcd-ef1234567890",
  "question_text": "Explain the process of photosynthesis.",
  "student_answer": "Photosynthesis is when plants make food using sunlight, water, and carbon dioxide.",
  "master_answer_id": "7b3c4f4e-2c6e-4a9b-9f25-9f3e2c0a9c1a",
  "teacher_feedback": "None",
  "AI_generated_feedback": "The answer correctly explains the core idea of photosynthesis but lacks mention of oxygen as a byproduct.",
  "rewarded_marks": 4,
  "max_marks": 5,
  "created_at": "2026-02-20T12:10:45.456789Z",
  "updated_at": "2026-02-20T12:10:45.456789Z"
}
